# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = np.arange(10)
fig, ax = plt.subplots()
ax.plot(
    x, x, label='y=x',
    marker='d',
    color='lightcoral',
    linestyle=':'
)
ax.plot(
    x, x**2, label='y=x^2',
    marker='*',
    color='lightpink',
    linestyle='-'
)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.legend(
    loc='upper left',
    shadow=True,
    fancybox=True,
    borderpad=1
)

fig.savefig("plot.png")

# %%
# 함수형식
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def main():
    
    x = np.arange(10)

    # 초기 figure와 축을 설정
    fig, ax = plt.subplots()
    
    # y = x 그래프
    ax.plot(x, x, label='y=x', marker='d', color='thistle', linestyle=':')
    # y = x^2 그래프
    ax.plot(x, x**2, label='y=x^2', marker='P', color='plum', linestyle='--')
    
    # 그래프 제목을 'Graph'로 설정합니다.
    ax.set_title('Graph')
    
    # x label은 'x', y label은 'y'로 설정합니다.
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    
    # x 범위는 0부터 10까지, y 범위는 0부터 100까지로 설정합니다.
    ax.set_xlim(0, 10)
    ax.set_ylim(0, 100)
    
    # 범례의 위치는 'upper left'로, 그림자 효과는 넣고, 테두리는 둥글게 합니다.
    ax.legend(loc ='upper left', shadow=True, fancybox=True)
    
    # figure를 "plot.png"라는 이름으로 저장하세요.
    fig.savefig('plot.png')

if __name__ == "__main__":
    main()
